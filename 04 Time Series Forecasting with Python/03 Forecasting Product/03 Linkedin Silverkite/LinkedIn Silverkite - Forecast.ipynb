# %% [markdown]
# # Linkedin Silverkite

# %%
import warnings
warnings.simplefilter('ignore')

# %%
# libraries
import numpy as np
import pandas as pd
from greykite.framework.templates.autogen.forecast_config import *
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.common.features.timeseries_features import *
from greykite.common.evaluation import EvaluationMetricEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from plotly.offline import iplot

# %%
# load the data
# YYYY-MM-DD
df = pd.read_csv('../../_data/nyc_data.csv')
future_df = pd.read_csv('../../_data/future.csv')
future_df.head()
# Out:
#        Date  Demand  Easter  Thanksgiving  Christmas  Temperature  Marketing
# 0  1/1/2021     NaN       0             0          0         5.00    154.221
# 1  1/2/2021     NaN       0             0          0        11.11    264.805
# 2  1/3/2021     NaN       0             0          0         3.89    115.499
# 3  1/4/2021     NaN       0             0          0         6.67    124.650
# 4  1/5/2021     NaN       0             0          0         5.56     77.968

# %%
# get the best parameters
parameters  = pd.read_csv("../../02 Parameter Tuning/03 Linkedin Silverkite/out/best_params_silverkite.csv",
                          index_col=0)
parameters
# Out:
#                                     [('estimator__growth_term', 'sqrt'), ('estimator__fit_algorithm_dict', {'fit_algorithm': 'linear'})]
# mean_test_RMSE                                                                    47.8
# param_estimator__fit_algorithm_dict                        {'fit_algorithm': 'linear'}
# param_estimator__growth_term                                                      sqrt

# %%
# get the parameters
growth_term_param = parameters.loc["param_estimator__growth_term"][0]
fit_algorithm_param = parameters.loc["param_estimator__fit_algorithm_dict"][0]

# %%
# merging both
df = pd.concat([df, future_df])
df = df.reset_index(drop=True)
df.head()
# Out:
#        Date      Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 0  1/1/2015  720.000885       0             0          0         3.68
# 1  1/2/2015  581.276773       0             0          0         4.73
# 2  1/3/2015  754.117039       0             0          0         7.23
# 3  1/4/2015  622.252774       0             0          0        10.96
# 4  1/5/2015  785.373319       0             0          0         6.92
#
#    Marketing
# 0     41.305
# 1    131.574
# 2    162.700
# 3    160.281
# 4     51.077

# %%
# inspecting df
df.tail()
# Out:
#            Date  Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 2218  1/27/2021     NaN       0             0          0         3.33
# 2219  1/28/2021     NaN       0             0          0         1.67
# 2220  1/29/2021     NaN       0             0          0        -2.78
# 2221  1/30/2021     NaN       0             0          0         1.11
# 2222  1/31/2021     NaN       0             0          0         4.44
#
#       Marketing
# 2218     39.664
# 2219    195.314
# 2220    235.894
# 2221    152.752
# 2222    158.620

# %%
# Rename variable
df = df.rename(columns={'Demand': 'y'})
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Date, y, Easter, Thanksgiving, Christmas, Temperature, Marketing]
# Index: []

# %% [markdown]
# ## Silverkite Preparations

# %%
# Specifying Time Series names
metadata = MetadataParam(time_col="Date",
                         value_col="y",
                         freq="D",
                         train_end_date=pd.to_datetime("2020-12-31"))
metadata
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='D', time_col='Date', train_end_date=Timestamp('2020-12-31 00:00:00'), value_col='y')

# %%
# growth terms possibilities
growth = dict(growth_term=growth_term_param)
growth
# Out:
# {'growth_term': 'sqrt'}

# %%
# seasonalities
seasonality = dict(yearly_seasonality="auto",
                   quarterly_seasonality="auto",
                   monthly_seasonality="auto",
                   weekly_seasonality="auto",
                   daily_seasonality="auto")
seasonality
# Out:
# {'yearly_seasonality': 'auto',
#  'quarterly_seasonality': 'auto',
#  'monthly_seasonality': 'auto',
#  'weekly_seasonality': 'auto',
#  'daily_seasonality': 'auto'}

# %%
# Specifying events
events = dict(holidays_to_model_separately=["New Year's Day"],
              holiday_lookup_countries=["US"],
              holiday_pre_num_days=2,
              holiday_post_num_days=2,
              holiday_pre_post_num_dict={"New Year's Day": (3,1)},
              daily_event_df_dict = {"elections": pd.DataFrame({
                "date": ["2016-11-08", "2020-11-03"],
                "event_name": ["elections"] * 2
              })})
events
# Out:
# {'holidays_to_model_separately': ["New Year's Day"],
#  'holiday_lookup_countries': ['US'],
#  'holiday_pre_num_days': 2,
#  'holiday_post_num_days': 2,
#  'holiday_pre_post_num_dict': {"New Year's Day": (3, 1)},
#  'daily_event_df_dict': {'elections':          date event_name
#   0  2016-11-08  elections
#   1  2020-11-03  elections}}

# %%
# Changepoints -> reflects the changes in the trend
changepoints = dict(changepoints_dict=dict(method="auto"))

# %%
# Regressors
regressors = dict(regressor_cols=["Easter", "Temperature", "Marketing"])
regressors
# Out:
# {'regressor_cols': ['Easter', 'Temperature', 'Marketing']}

# %%
# Lagged Regressors
lagged_regressors = dict(lagged_regressor_dict={"Temperature": "auto",
                                                "Easter": "auto",
                                                "Marketing": "auto"})

# %%
# autogression -> dependent on the forecasting horizon
autoregression = dict(autoreg_dict="auto")

# %%
fit_algorithm_param
# Out:
# "{'fit_algorithm': 'linear'}"

# %%
# Fitting algorithms
import yaml
custom = dict(fit_algorithm_dict=yaml.safe_load(fit_algorithm_param))
custom
# Out:
# {'fit_algorithm_dict': {'fit_algorithm': 'linear'}}

# %% [markdown]
# ## Silverkite Model

# %%
# Build the model
model_components = ModelComponentsParam(growth=growth,
                                        seasonality=seasonality,
                                        events=events,
                                        changepoints=changepoints,
                                        regressors=regressors,
                                        lagged_regressors=lagged_regressors,
                                        autoregression=autoregression,
                                        custom=custom)

# %%
# Cross-validation
evaluation_period = EvaluationPeriodParam(cv_min_train_periods=df.shape[0] - 180 - 31,
                                          cv_expanding_window=True,
                                          cv_max_splits=50,
                                          cv_periods_between_splits=16)

# %%
# Evaluation metric
evaluation_metric = EvaluationMetricParam(
    cv_selection_metric = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
# Configuration
config = ForecastConfig(model_template=ModelTemplateEnum.SILVERKITE.name,
                        forecast_horizon=31,
                        metadata_param=metadata,
                        model_components_param=model_components,
                        evaluation_period_param=evaluation_period,
                        evaluation_metric_param=evaluation_metric)

# %%
# Forecasting
forecaster = Forecaster()
result = forecaster.run_forecast_config(df=df,
                                        config=config)
# Out:
# Fitting 8 folds for each of 1 candidates, totalling 8 fits

# %%
# Look at the model summary
summary = result.model[-1].summary() # -1 retrieves the estimator from the pipeline
print(summary)
# Out:
# ============================ Forecast Model Summary ============================
#
# Number of observations: 2192,   Number of features: 182
# Method: Ordinary least squares
# Number of nonzero features: 182
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -165.2       -32.13      -0.9338        31.22        235.2
#
#             Pred_col Estimate Std. Err   t value Pr(>|t|) sig. code              95%CI
#            Intercept    64.06    3.195     20.05   <2e-16       ***     (57.79, 70.32)
# events_New Years Day   -16.02    22.53   -0.7108    0.477              (-60.21, 28.17)
#  events_N...rs Day-1   -48.39    22.51     -2.15    0.032         *   (-92.53, -4.255)
#  events_N...rs Day-2    -7.17    22.53   -0.3182    0.750              (-51.36, 37.02)
#  events_N...rs Day-3   -41.31    22.48    -1.838    0.066         .     (-85.4, 2.778)
#  events_N...rs Day+1  -0.1647    22.45 -0.007335    0.994              (-44.18, 43.86)
#         events_Other   -6.531    6.752   -0.9673    0.334               (-19.77, 6.71)
#       events_Other-1   -5.075    6.749   -0.7519    0.452              (-18.31, 8.161)
#       events_Other-2    9.288    6.772     1.371    0.170              (-3.994, 22.57)
#       events_Other+1  0.07857    6.758   0.01163    0.991              (-13.18, 13.33)
#       events_Other+2   -16.91    6.793     -2.49    0.013         *   (-30.23, -3.591)
#     events_elections   -10.51    36.36   -0.2891    0.773              (-81.82, 60.79)
#        str_dow_2-Tue   -17.68    8.713     -2.03    0.043         *  (-34.77, -0.5961)
#        str_dow_3-Wed    49.82    8.398     5.933 3.48e-09       ***     (33.36, 66.29)
#        str_dow_4-Thu    19.44    7.853     2.475    0.013         *     (4.036, 34.84)
#        str_dow_5-Fri   -36.02     7.93    -4.542 5.89e-06       ***   (-51.57, -20.47)
#        str_dow_6-Sat    17.49    8.333     2.099    0.036         *     (1.153, 33.84)
#        str_dow_7-Sun  -0.1372      9.0  -0.01524    0.988              (-17.79, 17.51)
#               Easter   -10.53    21.01   -0.5012    0.616              (-51.73, 30.67)
#          Temperature   -20.25    13.94    -1.453    0.146              (-47.58, 7.077)
#            Marketing    3.367    5.489    0.6135    0.540              (-7.397, 14.13)
#              ct_sqrt    43.66    23.38     1.867    0.062         .      (-2.19, 89.5)
#   is_weekend:ct_sqrt    33.87    20.95     1.617    0.106              (-7.217, 74.95)
#  str_dow_...:ct_sqrt   -23.53    45.09   -0.5218    0.602               (-112.0, 64.9)
#  str_dow_...:ct_sqrt    41.88    34.38     1.218    0.223              (-25.54, 109.3)
#  str_dow_...:ct_sqrt   -25.91    36.28   -0.7143    0.475              (-97.05, 45.23)
#  str_dow_...:ct_sqrt    41.93    36.37     1.153    0.249               (-29.4, 113.3)
#  str_dow_...:ct_sqrt    5.804    33.59    0.1728    0.863              (-60.07, 71.67)
#  str_dow_...:ct_sqrt    28.06    38.58    0.7275    0.467              (-47.59, 103.7)
#    cp0_2016_01_26_00    257.7    32.81     7.856 6.34e-15       ***     (193.4, 322.1)
#  is_weeke...01_26_00    5.343    30.25    0.1767    0.860              (-53.97, 64.66)
#  str_dow_...01_26_00   -66.92    63.98    -1.046    0.296              (-192.4, 58.55)
#  str_dow_...01_26_00    69.53    48.65     1.429    0.153              (-25.89, 164.9)
#  str_dow_...01_26_00    48.78    52.07    0.9369    0.349              (-53.33, 150.9)
#  str_dow_...01_26_00   -14.69    51.98   -0.2826    0.777              (-116.6, 87.25)
#  str_dow_...01_26_00    63.51    47.97     1.324    0.186              (-30.56, 157.6)
#  str_dow_...01_26_00   -58.14    55.09    -1.055    0.291               (-166.2, 49.9)
#    cp1_2017_09_03_00   -812.6    194.6    -4.175 3.11e-05       ***  (-1194.0, -430.9)
#  is_weeke...09_03_00    60.69    168.6    0.3599    0.719              (-270.0, 391.4)
#  str_dow_...09_03_00   -103.2    355.5   -0.2904    0.772              (-800.5, 594.0)
#  str_dow_...09_03_00   -382.1    269.8    -1.417    0.157              (-911.2, 146.9)
#  str_dow_...09_03_00   -73.39    293.3   -0.2502    0.802              (-648.6, 501.8)
#  str_dow_...09_03_00   -64.43    292.1   -0.2206    0.825              (-637.3, 508.4)
#  str_dow_...09_03_00   -18.07    269.4  -0.06706    0.947              (-546.5, 510.3)
#  str_dow_...09_03_00    78.74    308.4    0.2553    0.798              (-526.0, 683.5)
#    cp2_2017_11_07_00   1988.0    289.7     6.861 8.99e-12       ***   (1420.0, 2556.0)
#  is_weeke...11_07_00    170.7    245.6    0.6949    0.487              (-311.0, 652.4)
#  str_dow_...11_07_00    335.0    517.0     0.648    0.517             (-678.8, 1349.0)
#  str_dow_...11_07_00    583.4    392.9     1.485    0.138             (-187.1, 1354.0)
#  str_dow_...11_07_00    484.7    427.0     1.135    0.256             (-352.7, 1322.0)
#  str_dow_...11_07_00    33.48    425.1   0.07875    0.937              (-800.3, 867.2)
#  str_dow_...11_07_00    232.9    392.1    0.5941    0.553             (-536.0, 1002.0)
#  str_dow_...11_07_00   -62.03    448.9   -0.1382    0.890              (-942.3, 818.2)
#    cp3_2018_02_24_00  -1374.0    157.2    -8.741   <2e-16       *** (-1683.0, -1066.0)
#  is_weeke...02_24_00   -208.1    132.2    -1.574    0.116              (-467.4, 51.22)
#  str_dow_...02_24_00   -231.4    278.5   -0.8308    0.406              (-777.6, 314.8)
#  str_dow_...02_24_00   -133.9    212.0   -0.6316    0.528              (-549.6, 281.8)
#  str_dow_...02_24_00   -504.9    230.1    -2.194    0.028         *   (-956.1, -53.66)
#  str_dow_...02_24_00    143.8    228.7    0.6289    0.530              (-304.7, 592.3)
#  str_dow_...02_24_00   -305.8    210.9     -1.45    0.147              (-719.5, 107.8)
#  str_dow_...02_24_00    97.45    241.7    0.4031    0.687              (-376.6, 571.5)
#    cp4_2018_09_29_00    593.6    266.0     2.231    0.026         *    (71.91, 1115.0)
#  is_weeke...09_29_00    188.6    234.5     0.804    0.422              (-271.4, 648.5)
#  str_dow_...09_29_00   -476.9    496.1   -0.9613    0.337             (-1450.0, 496.0)
#  str_dow_...09_29_00   -243.8    377.6   -0.6457    0.519              (-984.2, 496.7)
#  str_dow_...09_29_00    179.7    409.7    0.4387    0.661              (-623.7, 983.1)
#  str_dow_...09_29_00   -578.1    406.1    -1.423    0.155             (-1375.0, 218.4)
#  str_dow_...09_29_00    756.7    374.0     2.023    0.043         *    (23.22, 1490.0)
#  str_dow_...09_29_00   -567.2    428.3    -1.324    0.186             (-1407.0, 272.7)
#    cp5_2018_11_11_00    257.2    324.1    0.7935    0.428              (-378.4, 892.8)
#  is_weeke...11_11_00   -147.1    278.3   -0.5285    0.597              (-692.9, 398.7)
#  str_dow_...11_11_00    345.9    588.3    0.5879    0.557             (-807.9, 1500.0)
#  str_dow_...11_11_00    445.0    447.8    0.9938    0.320             (-433.1, 1323.0)
#  str_dow_...11_11_00    47.51    486.0   0.09774    0.922             (-905.7, 1001.0)
#  str_dow_...11_11_00    529.3    482.0     1.098    0.272             (-416.0, 1475.0)
#  str_dow_...11_11_00   -548.5    443.9    -1.236    0.217             (-1419.0, 322.1)
#  str_dow_...11_11_00    400.7    508.0    0.7887    0.430             (-595.6, 1397.0)
#    cp6_2019_02_06_00   -776.7    120.4    -6.448 1.40e-10       ***  (-1013.0, -540.5)
#  is_weeke...02_06_00    75.48    97.97    0.7704    0.441              (-116.7, 267.6)
#  str_dow_...02_06_00    130.9    206.6    0.6335    0.526              (-274.2, 536.0)
#  str_dow_...02_06_00   -221.8    157.2    -1.411    0.158              (-530.1, 86.51)
#  str_dow_...02_06_00   -92.97    170.8   -0.5443    0.586              (-427.9, 242.0)
#  str_dow_...02_06_00   -8.348    169.5  -0.04927    0.961              (-340.7, 324.0)
#  str_dow_...02_06_00   -133.7    156.2   -0.8565    0.392              (-440.0, 172.5)
#  str_dow_...02_06_00    209.0    178.8     1.169    0.242              (-141.6, 559.6)
#    cp7_2019_12_07_00   -538.5    68.02    -7.916 3.96e-15       ***   (-671.9, -405.1)
#  is_weeke...12_07_00   0.3819    54.82  0.006966    0.994              (-107.1, 107.9)
#  str_dow_...12_07_00   -6.311    115.6   -0.0546    0.956              (-233.0, 220.3)
#  str_dow_...12_07_00   -182.5    88.01    -2.073    0.038         *   (-355.1, -9.877)
#  str_dow_...12_07_00   -35.65    95.53   -0.3732    0.709              (-223.0, 151.7)
#  str_dow_...12_07_00   -92.42     94.8   -0.9749    0.330              (-278.3, 93.49)
#  str_dow_...12_07_00    65.05    87.29    0.7451    0.456              (-106.1, 236.2)
#  str_dow_...12_07_00    -64.5    99.82   -0.6461    0.518              (-260.3, 131.3)
#    cp8_2020_02_10_00    390.9    56.85     6.876 8.11e-12       ***     (279.4, 502.4)
#  is_weeke...02_10_00   -10.71    45.68   -0.2345    0.815              (-100.3, 78.87)
#  str_dow_...02_10_00   -28.55    96.08   -0.2972    0.766              (-217.0, 159.9)
#  str_dow_...02_10_00    120.6    73.12      1.65    0.099         .    (-22.76, 264.0)
#  str_dow_...02_10_00    61.34    79.39    0.7726    0.440              (-94.36, 217.0)
#  str_dow_...02_10_00    83.11    78.94     1.053    0.293               (-71.7, 237.9)
#  str_dow_...02_10_00   -46.07    72.57   -0.6347    0.526              (-188.4, 96.26)
#  str_dow_...02_10_00    35.21     83.0    0.4242    0.671              (-127.6, 198.0)
#  ct_sqrt:...w_weekly    14.28    21.44    0.6663    0.505              (-27.76, 56.32)
#  ct_sqrt:...w_weekly    5.813    41.09    0.1415    0.888              (-74.76, 86.39)
#  ct_sqrt:...w_weekly    25.39    25.67    0.9892    0.323              (-24.95, 75.73)
#  ct_sqrt:...w_weekly  -0.4187    36.39  -0.01151    0.991              (-71.78, 70.94)
#  cp0_2016...w_weekly    45.66    30.28     1.508    0.132              (-13.72, 105.0)
#  cp0_2016...w_weekly    71.18    58.56     1.215    0.224              (-43.66, 186.0)
#  cp0_2016...w_weekly   0.7403     36.6   0.02023    0.984              (-71.03, 72.51)
#  cp0_2016...w_weekly    106.8    51.73     2.064    0.039         *     (5.302, 208.2)
#  cp1_2017...w_weekly   -225.4    169.1    -1.333    0.183              (-557.1, 106.2)
#  cp1_2017...w_weekly     2.37    328.2  0.007221    0.994              (-641.2, 646.0)
#  cp1_2017...w_weekly    25.89    204.8    0.1264    0.899              (-375.7, 427.5)
#  cp1_2017...w_weekly    45.78    288.9    0.1585    0.874              (-520.8, 612.4)
#  cp2_2017...w_weekly    467.9    246.0     1.902    0.057         .    (-14.53, 950.4)
#  cp2_2017...w_weekly   -19.94    477.7  -0.04175    0.967              (-956.8, 916.9)
#  cp2_2017...w_weekly   -29.12    298.0  -0.09774    0.922              (-613.5, 555.2)
#  cp2_2017...w_weekly    -16.7    420.5  -0.03971    0.968              (-841.3, 807.9)
#  cp3_2018...w_weekly   -159.0    132.5      -1.2    0.230              (-418.8, 100.9)
#  cp3_2018...w_weekly   -22.54    257.4  -0.08755    0.930              (-527.3, 482.3)
#  cp3_2018...w_weekly    89.97    160.6    0.5603    0.575              (-224.9, 404.8)
#  cp3_2018...w_weekly   -97.01    226.6   -0.4281    0.669              (-541.4, 347.4)
#  cp4_2018...w_weekly   -263.7    235.8    -1.118    0.264              (-726.1, 198.8)
#  cp4_2018...w_weekly    616.9    457.4     1.349    0.178             (-280.2, 1514.0)
#  cp4_2018...w_weekly    -4.37    285.7  -0.01529    0.988              (-564.6, 555.9)
#  cp4_2018...w_weekly    582.4    403.1     1.445    0.149             (-208.1, 1373.0)
#  cp5_2018...w_weekly    400.2    279.7     1.431    0.153              (-148.2, 948.7)
#  cp5_2018...w_weekly   -490.7    542.6   -0.9044    0.366             (-1555.0, 573.3)
#  cp5_2018...w_weekly   -23.66    339.2  -0.06975    0.944              (-688.8, 641.5)
#  cp5_2018...w_weekly   -326.3    478.1   -0.6825    0.495             (-1264.0, 611.3)
#  cp6_2019...w_weekly   -62.68    98.17   -0.6385    0.523              (-255.2, 129.8)
#  cp6_2019...w_weekly   -116.4    190.6   -0.6106    0.542              (-490.3, 257.5)
#  cp6_2019...w_weekly    47.07    119.4    0.3944    0.693              (-187.0, 281.1)
#  cp6_2019...w_weekly   -222.2    168.0    -1.323    0.186              (-551.6, 107.2)
#  cp7_2019...w_weekly   -56.53    54.94    -1.029    0.304              (-164.3, 51.22)
#  cp7_2019...w_weekly   -36.77    106.6   -0.3451    0.730              (-245.7, 172.2)
#  cp7_2019...w_weekly     93.8     66.7     1.406    0.160               (-37.0, 224.6)
#  cp7_2019...w_weekly   -65.36    93.85   -0.6965    0.486              (-249.4, 118.7)
#  cp8_2020...w_weekly     85.3    45.73     1.865    0.062         .    (-4.381, 175.0)
#  cp8_2020...w_weekly    43.86    88.57    0.4952    0.621              (-129.8, 217.5)
#  cp8_2020...w_weekly   -28.95    55.32   -0.5233    0.601              (-137.4, 79.54)
#  cp8_2020...w_weekly    129.4    77.89     1.661    0.097         .    (-23.36, 282.2)
#      sin1_tow_weekly     53.5    8.886      6.02 2.05e-09       ***     (36.07, 70.93)
#      cos1_tow_weekly    40.88     11.7     3.494 4.86e-04       ***     (17.93, 63.83)
#      sin2_tow_weekly   -6.174    8.901   -0.6936    0.488              (-23.63, 11.28)
#      cos2_tow_weekly    11.49    11.71    0.9808    0.327              (-11.48, 34.45)
#      sin3_tow_weekly    42.89    6.264     6.847 9.93e-12       ***     (30.61, 55.18)
#      cos3_tow_weekly    79.21    11.71     6.762 1.77e-11       ***     (56.24, 102.2)
#      sin4_tow_weekly    21.17    6.142     3.446 5.80e-04       ***     (9.123, 33.21)
#   sin4_toq_quarterly   0.5476    3.032    0.1806    0.857              (-5.398, 6.494)
#   cos4_toq_quarterly     4.27    3.093     1.381    0.168              (-1.795, 10.33)
#   sin5_toq_quarterly   0.8251    3.031    0.2723    0.785              (-5.119, 6.769)
#   cos5_toq_quarterly  -0.1286    3.073  -0.04187    0.967              (-6.154, 5.897)
#      sin1_ct1_yearly    81.87    6.173     13.26   <2e-16       ***     (69.77, 93.98)
#      cos1_ct1_yearly    144.8    7.632     18.98   <2e-16       ***     (129.9, 159.8)
#      sin2_ct1_yearly   -34.65      3.5    -9.902   <2e-16       ***   (-41.52, -27.79)
#      cos2_ct1_yearly    40.69    3.141     12.96   <2e-16       ***     (34.53, 46.85)
#      sin3_ct1_yearly    8.977    3.119     2.878    0.004        **      (2.86, 15.09)
#      cos3_ct1_yearly    16.94    3.121     5.427 6.41e-08       ***     (10.82, 23.06)
#      sin4_ct1_yearly   -6.972    3.029    -2.301    0.021         *   (-12.91, -1.031)
#      cos4_ct1_yearly    15.95    3.107     5.135 3.09e-07       ***      (9.86, 22.05)
#      sin5_ct1_yearly   -11.32    3.042    -3.721 2.04e-04       ***   (-17.28, -5.353)
#      cos5_ct1_yearly   -4.664    3.088     -1.51    0.131              (-10.72, 1.392)
#      sin6_ct1_yearly   0.3356    3.028    0.1108    0.912              (-5.603, 6.274)
#      cos6_ct1_yearly   -2.909    3.151   -0.9233    0.356               (-9.088, 3.27)
#      sin7_ct1_yearly   -11.55    3.045    -3.793 1.53e-04       ***   (-17.52, -5.576)
#      cos7_ct1_yearly    1.802      3.1    0.5813    0.561              (-4.278, 7.883)
#      sin8_ct1_yearly   -5.157     3.04    -1.696    0.090         .   (-11.12, 0.8055)
#      cos8_ct1_yearly   -7.978    3.143    -2.538    0.011         *   (-14.14, -1.813)
#      sin9_ct1_yearly    4.254    3.026     1.406    0.160              (-1.679, 10.19)
#      cos9_ct1_yearly    0.558    3.088    0.1807    0.857              (-5.498, 6.614)
#     sin10_ct1_yearly   -7.597    3.032    -2.505    0.012         *    (-13.54, -1.65)
#     cos10_ct1_yearly    -6.48    3.099    -2.091    0.037         *  (-12.56, -0.4033)
#     sin11_ct1_yearly    12.03    3.028     3.973 7.33e-05       ***     (6.093, 17.97)
#     cos11_ct1_yearly   -7.059    3.197    -2.208    0.027         *  (-13.33, -0.7885)
#     sin12_ct1_yearly  -0.2524    3.029  -0.08333    0.934              (-6.194, 5.689)
#     cos12_ct1_yearly   -3.725      3.1    -1.202    0.230              (-9.804, 2.354)
#     sin13_ct1_yearly    1.481    3.077    0.4815    0.630              (-4.552, 7.515)
#     cos13_ct1_yearly    6.435     3.09     2.083    0.037         *    (0.3763, 12.49)
#     sin14_ct1_yearly   -5.552    3.124    -1.777    0.076         .   (-11.68, 0.5743)
#     cos14_ct1_yearly    3.644    3.088      1.18    0.238                (-2.412, 9.7)
#     sin15_ct1_yearly   -1.997    3.089   -0.6466    0.518               (-8.055, 4.06)
#     cos15_ct1_yearly    4.598    3.089     1.488    0.137               (-1.46, 10.66)
# Signif. Code: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Multiple R-squared: 0.8987,   Adjusted R-squared: 0.8927
# F-statistic: 147.93 on 123 and 2067 DF,   p-value: 1.110e-16
# Model AIC: 34120.0,   model BIC: 34832.0
#
# WARNING: the condition number is large, 6.24e+19. This might indicate that there are strong multicollinearity or other numerical problems.

# %%
# visualization
fig = result.forecast.plot_components()
iplot(fig)
# Out:
# <div>                            <div id="c8f615a2-46ce-4073-9e0b-f214b1b019db" class="plotly-graph-div" style="height:1050px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8f615a2-46ce-4073-9e0b-f214b1b019db")) {                    Plotly.newPlot(                        "c8f615a2-46ce-4073-9e0b-f214b1b019db",                        [{"line":{"color":"rgb(127, 60, 141)"},"name":"Intercept","opacity":0.8,"x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","201 ...

# %%
# getting the forecast result
forecast = result.forecast.df[["ts", "forecast"]]
forecast = forecast.rename(columns={'forecast': 'silverkite'})
predictions_silverkite = forecast.iloc[-31:, :]
predictions_silverkite
# Out:
#              ts  silverkite
# 2192 2021-01-01  751.509648
# 2193 2021-01-02  836.244799
# 2194 2021-01-03  754.438222
# 2195 2021-01-04  898.366173
# 2196 2021-01-05  781.204767
# 2197 2021-01-06  915.563305
# 2198 2021-01-07  827.511744
# 2199 2021-01-08  755.982269
# 2200 2021-01-09  823.150542
# 2201 2021-01-10  738.205218
# 2202 2021-01-11  887.305124
# 2203 2021-01-12  771.889920
# 2204 2021-01-13  902.856809
# 2205 2021-01-14  821.328862
# 2206 2021-01-15  749.196438
# 2207 2021-01-16  827.898930
# 2208 2021-01-17  734.266807
# 2209 2021-01-18  882.793425
# 2210 2021-01-19  775.373648
# 2211 2021-01-20  891.872828
# 2212 2021-01-21  827.722604
# 2213 2021-01-22  754.263496
# 2214 2021-01-23  822.911516
# 2215 2021-01-24  743.223424
# 2216 2021-01-25  887.833295
# 2217 2021-01-26  773.435272
# 2218 2021-01-27  899.745275
# 2219 2021-01-28  818.571284
# 2220 2021-01-29  746.552907
# 2221 2021-01-30  804.067556
# 2222 2021-01-31  718.861934

# %%
# exporting
predictions_silverkite.to_csv("./out/predictions_silverkite.csv")
